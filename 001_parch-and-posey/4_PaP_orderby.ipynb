# %%
import sqlite3
import pandas as pd

# %%
conn =sqlite3.connect('parch-and-posey.db')

# %%
tables = pd.read_sql_query(sql = 'select * from sqlite_master where type = "table";', con = conn)

# %%
tables
# Out:
#     type        name    tbl_name  rootpage  \
# 0  table  web_events  web_events         2
# 1  table  sales_reps  sales_reps         7
# 2  table      region      region       222
# 3  table      orders      orders       223
# 4  table    accounts    accounts       583
#
#                                                  sql
# 0  CREATE TABLE web_events (\tid integer,\taccoun...
# 1  CREATE TABLE sales_reps (\tid integer,\tname b...
# 2   CREATE TABLE region (\tid integer,\tname bpchar)
# 3  CREATE TABLE orders (\tid integer,\taccount_id...
# 4  CREATE TABLE accounts (\tid integer,\tname bpc...

# %%
orders_df = pd.read_sql_query(sql = 'select * from orders order by occurred_at DESC limit 10;', con = conn)

# %%
orders_df
# Out:
#      id  account_id          occurred_at  standard_qty  gloss_qty  poster_qty  \
# 0  6451        3841  2017-01-02 00:02:40            42        506         302
# 1  3546        3841  2017-01-01 23:50:16           291         36          26
# 2  6454        3861  2017-01-01 22:29:50            38        167          51
# 3  3554        3861  2017-01-01 22:17:26           497          0          23
# 4  6556        4051  2017-01-01 21:04:25             0         65          50
# 5  3745        4051  2017-01-01 20:52:23           495         15           0
# 6  1092        1761  2017-01-01 17:34:10            62         28         124
# 7  1364        1961  2017-01-01 16:40:57           102         39          29
# 8  3159        3431  2017-01-01 14:05:39           302         29          18
# 9  6223        3431  2017-01-01 13:57:21            51        444         135
#
#    total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  total_amt_usd
# ...

# %%
orders_df.dtypes
# Out:
# id                    int64
# account_id            int64
# occurred_at          object
# standard_qty          int64
# gloss_qty             int64
# poster_qty            int64
# total                 int64
# standard_amt_usd    float64
# gloss_amt_usd       float64
# poster_amt_usd      float64
# total_amt_usd       float64
# dtype: object

# %%
orders_df['occurred_at'] = pd.to_datetime(orders_df['occurred_at'], format='%Y-%m-%d %H:%M:%S')

# %%
orders_df
# Out:
#      id  account_id         occurred_at  standard_qty  gloss_qty  poster_qty  \
# 0  6451        3841 2017-01-02 00:02:40            42        506         302
# 1  3546        3841 2017-01-01 23:50:16           291         36          26
# 2  6454        3861 2017-01-01 22:29:50            38        167          51
# 3  3554        3861 2017-01-01 22:17:26           497          0          23
# 4  6556        4051 2017-01-01 21:04:25             0         65          50
# 5  3745        4051 2017-01-01 20:52:23           495         15           0
# 6  1092        1761 2017-01-01 17:34:10            62         28         124
# 7  1364        1961 2017-01-01 16:40:57           102         39          29
# 8  3159        3431 2017-01-01 14:05:39           302         29          18
# 9  6223        3431 2017-01-01 13:57:21            51        444         135
#
#    total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  total_amt_usd
# ...

# %%
orders_df.dtypes
# Out:
# id                           int64
# account_id                   int64
# occurred_at         datetime64[ns]
# standard_qty                 int64
# gloss_qty                    int64
# poster_qty                   int64
# total                        int64
# standard_amt_usd           float64
# gloss_amt_usd              float64
# poster_amt_usd             float64
# total_amt_usd              float64
# dtype: object
