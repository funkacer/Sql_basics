# %%
import sqlite3
import pandas as pd

# %%
conn =sqlite3.connect('parch-and-posey.db')

# %%
tables = pd.read_sql_query(sql = 'select * from sqlite_master where type = "table";', con = conn)

# %%
tables
# Out:
#     type        name    tbl_name  rootpage  \
# 0  table  web_events  web_events         2
# 1  table  sales_reps  sales_reps         6
# 2  table      region      region         7
# 3  table      orders      orders         8
# 4  table    accounts    accounts        94
#
#                                                  sql
# 0  CREATE TABLE web_events (\tid integer,\taccoun...
# 1  CREATE TABLE sales_reps (\tid integer,\tname b...
# 2   CREATE TABLE region (\tid integer,\tname bpchar)
# 3  CREATE TABLE orders (\tid integer,\taccount_id...
# 4  CREATE TABLE accounts (\tid integer,\tname bpc...

# %%
web_events_df = pd.read_sql_query(sql = 'select * from web_events;', con = conn)

# %%
web_events_df
# Out:
#         id  account_id          occurred_at   channel
# 0        1        1001  2015-10-06 17:13:58    direct
# 1        2        1001  2015-11-05 03:08:26    direct
# 2        3        1001  2015-12-04 03:57:24    direct
# 3        4        1001  2016-01-02 00:55:03    direct
# 4        5        1001  2016-02-01 19:02:33    direct
# ...    ...         ...                  ...       ...
# 9068  9069        4491  2016-10-04 15:43:29  facebook
# 9069  9070        4491  2016-10-04 23:42:41   twitter
# 9070  9071        4491  2016-11-06 07:23:45   organic
# 9071  9072        4491  2016-12-18 03:21:31   organic
# 9072  9073        4501  2016-05-30 00:46:53   organic
#
# [9073 rows x 4 columns]

# %%
web_events_df.dtypes
# Out:
# id              int64
# account_id      int64
# occurred_at    object
# channel        object
# dtype: object

# %%
web_events_df['occurred_at'] = pd.to_datetime(web_events_df['occurred_at'], format='%Y-%m-%d %H:%M:%S')

# %%
web_events_df
# Out:
#         id  account_id         occurred_at   channel
# 0        1        1001 2015-10-06 17:13:58    direct
# 1        2        1001 2015-11-05 03:08:26    direct
# 2        3        1001 2015-12-04 03:57:24    direct
# 3        4        1001 2016-01-02 00:55:03    direct
# 4        5        1001 2016-02-01 19:02:33    direct
# ...    ...         ...                 ...       ...
# 9068  9069        4491 2016-10-04 15:43:29  facebook
# 9069  9070        4491 2016-10-04 23:42:41   twitter
# 9070  9071        4491 2016-11-06 07:23:45   organic
# 9071  9072        4491 2016-12-18 03:21:31   organic
# 9072  9073        4501 2016-05-30 00:46:53   organic
#
# [9073 rows x 4 columns]

# %%
web_events_df.dtypes
# Out:
# id                      int64
# account_id              int64
# occurred_at    datetime64[ns]
# channel                object
# dtype: object

# %%
sales_reps_df = pd.read_sql_query(sql = 'select * from sales_reps;', con = conn)

# %%
sales_reps_df
# Out:
#         id                   name  region_id
# 0   321500          Samuel Racine          1
# 1   321510           Eugena Esser          1
# 2   321520        Michel Averette          1
# 3   321530          Renetta Carew          1
# 4   321540            Cara Clarke          1
# 5   321550            Lavera Oles          1
# 6   321560            Elba Felder          1
# 7   321570         Shawanda Selke          1
# 8   321580           Sibyl Lauria          1
# 9   321590         Necole Victory          1
# 10  321600      Ernestine Pickron          1
# 11  321610          Ayesha Monica          1
# 12  321620            Retha Sears          1
# 13  321630          Julia Behrman          1
# 14  321640              Tia Amato          1
# 15  321650        Akilah Drinkard          1
# 16  321660         Silvana Virden          1
# 17  321670           Nakesha Renn          1
# 18  321680          Elna Condello          1
# 19  321690          Gianna Dossey          1
# ...

# %%
region_df = pd.read_sql_query(sql = 'select * from region;', con = conn)

# %%
region_df
# Out:
#    id       name
# 0   1  Northeast
# 1   2    Midwest
# 2   3  Southeast
# 3   4       West

# %%
orders_df = pd.read_sql_query(sql = 'select * from orders;', con = conn)

# %%
orders_df
# Out:
#         id  account_id          occurred_at  standard_qty  gloss_qty  \
# 0        1        1001  2015-10-06 17:31:14           123         22
# 1        2        1001  2015-11-05 03:34:33           190         41
# 2        3        1001  2015-12-04 04:21:55            85         47
# 3        4        1001  2016-01-02 01:18:24           144         32
# 4        5        1001  2016-02-01 19:27:27           108         29
# ...    ...         ...                  ...           ...        ...
# 6907  6908        4501  2016-06-29 04:03:39            11        199
# 6908  6909        4501  2016-07-29 19:58:32             5         91
# 6909  6910        4501  2016-08-27 00:58:11            16         94
# 6910  6911        4501  2016-11-22 06:52:22            63         67
# 6911  6912        4501  2016-12-21 13:30:42            61        150
#
#       poster_qty  total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# ...

# %%
orders_df.dtypes
# Out:
# id                    int64
# account_id            int64
# occurred_at          object
# standard_qty          int64
# gloss_qty             int64
# poster_qty            int64
# total                 int64
# standard_amt_usd    float64
# gloss_amt_usd       float64
# poster_amt_usd      float64
# total_amt_usd       float64
# dtype: object

# %%
orders_df['occurred_at'] = pd.to_datetime(orders_df['occurred_at'], format='%Y-%m-%d %H:%M:%S')

# %%
orders_df
# Out:
#         id  account_id         occurred_at  standard_qty  gloss_qty  \
# 0        1        1001 2015-10-06 17:31:14           123         22
# 1        2        1001 2015-11-05 03:34:33           190         41
# 2        3        1001 2015-12-04 04:21:55            85         47
# 3        4        1001 2016-01-02 01:18:24           144         32
# 4        5        1001 2016-02-01 19:27:27           108         29
# ...    ...         ...                 ...           ...        ...
# 6907  6908        4501 2016-06-29 04:03:39            11        199
# 6908  6909        4501 2016-07-29 19:58:32             5         91
# 6909  6910        4501 2016-08-27 00:58:11            16         94
# 6910  6911        4501 2016-11-22 06:52:22            63         67
# 6911  6912        4501 2016-12-21 13:30:42            61        150
#
#       poster_qty  total  standard_amt_usd  gloss_amt_usd  poster_amt_usd  \
# 0             24    169            613.77         164.78          194.88
# ...

# %%
orders_df.dtypes
# Out:
# id                           int64
# account_id                   int64
# occurred_at         datetime64[ns]
# standard_qty                 int64
# gloss_qty                    int64
# poster_qty                   int64
# total                        int64
# standard_amt_usd           float64
# gloss_amt_usd              float64
# poster_amt_usd             float64
# total_amt_usd              float64
# dtype: object

# %%
accounts_df = pd.read_sql_query(sql = 'select * from accounts;', con = conn)

# %%
accounts_df
# Out:
#        id                name                    website        lat  \
# 0    1001             Walmart            www.walmart.com  40.238496
# 1    1011         Exxon Mobil         www.exxonmobil.com  41.169156
# 2    1021               Apple              www.apple.com  42.290495
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021
# 4    1041            McKesson           www.mckesson.com  42.217093
# ..    ...                 ...                        ...        ...
# 346  4461                 KKR                www.kkr.com  45.545353
# 347  4471               Oneok              www.oneok.com  45.513513
# 348  4481      Newmont Mining            www.newmont.com  45.494117
# 349  4491                 PPL             www.pplweb.com  45.491720
# 350  4501         SpartanNash        www.spartannash.com  45.555651
#
#            long       primary_poc  sales_rep_id
# 0    -75.103297       Tamara Tuma        321500
# 1    -73.849374      Sung Shields        321510
# ...
