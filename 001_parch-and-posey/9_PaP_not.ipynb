# %%
import sqlite3
import pandas as pd
from IPython.display import display
from ipywidgets import HTML

# %%
conn =sqlite3.connect('parch-and-posey.db')

# %%
tables = pd.read_sql_query(sql = 'select * from sqlite_master where type = "table";', con = conn)

# %%
tables
# Out:
#     type        name    tbl_name  rootpage  \
# 0  table  web_events  web_events         2
# 1  table  sales_reps  sales_reps         7
# 2  table      region      region       222
# 3  table      orders      orders       223
# 4  table    accounts    accounts       583
#
#                                                  sql
# 0  CREATE TABLE web_events (\tid integer,\taccoun...
# 1  CREATE TABLE sales_reps (\tid integer,\tname b...
# 2   CREATE TABLE region (\tid integer,\tname bpchar)
# 3  CREATE TABLE orders (\tid integer,\taccount_id...
# 4  CREATE TABLE accounts (\tid integer,\tname bpc...

# %% [markdown]
# # NOT IN

# %%
pd.read_sql_query(sql = '''
SELECT name, primary_poc, sales_rep_id
FROM accounts
WHERE name NOT IN ('Walmart', 'Target', 'Nordstrom');
''', con = conn)
# Out:
#                    name       primary_poc  sales_rep_id
# 0           Exxon Mobil      Sung Shields        321510
# 1                 Apple        Jodee Lupo        321520
# 2    Berkshire Hathaway    Serafina Banda        321530
# 3              McKesson    Angeles Crusoe        321540
# 4    UnitedHealth Group    Savanna Gayman        321550
# ..                  ...               ...           ...
# 343                 KKR       Buffy Azure        321970
# 344               Oneok   Esta Engelhardt        321960
# 345      Newmont Mining  Khadijah Riemann        321970
# 346                 PPL   Deanne Hertlein        321960
# 347         SpartanNash      Jewell Likes        321970
#
# [348 rows x 3 columns]

# %%
pd.read_sql_query(sql = '''
SELECT *
FROM web_events
WHERE channel NOT IN ('organic', 'adwords');
''', con = conn)
# Out:
#         id  account_id          occurred_at   channel
# 0        1        1001  2015-10-06 17:13:58    direct
# 1        2        1001  2015-11-05 03:08:26    direct
# 2        3        1001  2015-12-04 03:57:24    direct
# 3        4        1001  2016-01-02 00:55:03    direct
# 4        5        1001  2016-02-01 19:02:33    direct
# ...    ...         ...                  ...       ...
# 7210  9066        4491  2016-07-18 21:31:10  facebook
# 7211  9067        4491  2016-08-14 15:41:44  facebook
# 7212  9068        4491  2016-09-11 19:18:07    banner
# 7213  9069        4491  2016-10-04 15:43:29  facebook
# 7214  9070        4491  2016-10-04 23:42:41   twitter
#
# [7215 rows x 4 columns]

# %%
display(HTML(pd.read_sql_query(sql = '''
SELECT *
FROM web_events 
WHERE account_id NOT IN (1001, 1011);
''', con = conn).to_html()))
# Out:
# HTML(value='<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></…

# %% [markdown]
# # NOT LIKE

# %%
pd.read_sql_query(sql = '''
SELECT *
FROM accounts
WHERE name NOT LIKE ('C%');
''', con = conn)
# Out:
#        id                name                    website        lat  \
# 0    1001             Walmart            www.walmart.com  40.238496
# 1    1011         Exxon Mobil         www.exxonmobil.com  41.169156
# 2    1021               Apple              www.apple.com  42.290495
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021
# 4    1041            McKesson           www.mckesson.com  42.217093
# ..    ...                 ...                        ...        ...
# 309  4461                 KKR                www.kkr.com  45.545353
# 310  4471               Oneok              www.oneok.com  45.513513
# 311  4481      Newmont Mining            www.newmont.com  45.494117
# 312  4491                 PPL             www.pplweb.com  45.491720
# 313  4501         SpartanNash        www.spartannash.com  45.555651
#
#            long       primary_poc  sales_rep_id
# 0    -75.103297       Tamara Tuma        321500
# 1    -73.849374      Sung Shields        321510
# 2    -76.084009        Jodee Lupo        321520
# 3    -75.763898    Serafina Banda        321530
# 4    -75.284998    Angeles Crusoe        321540
# ..          ...               ...           ...
# 309 -122.655247       Buffy Azure        321970
# 310 -122.681500   Esta Engelhardt        321960
# 311 -122.669460  Khadijah Riemann        321970
# 312 -122.671880   Deanne Hertlein        321960
# 313 -122.657145      Jewell Likes        321970
#
# [314 rows x 7 columns]

# %%
pd.read_sql_query(sql = '''
SELECT *
FROM accounts
WHERE name NOT LIKE ('%one%');
''', con = conn)
# Out:
#        id                name                    website        lat  \
# 0    1001             Walmart            www.walmart.com  40.238496
# 1    1011         Exxon Mobil         www.exxonmobil.com  41.169156
# 2    1021               Apple              www.apple.com  42.290495
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021
# 4    1041            McKesson           www.mckesson.com  42.217093
# ..    ...                 ...                        ...        ...
# 341  4451       Lithia Motors             www.lithia.com  45.504395
# 342  4461                 KKR                www.kkr.com  45.545353
# 343  4481      Newmont Mining            www.newmont.com  45.494117
# 344  4491                 PPL             www.pplweb.com  45.491720
# 345  4501         SpartanNash        www.spartannash.com  45.555651
#
#            long       primary_poc  sales_rep_id
# 0    -75.103297       Tamara Tuma        321500
# 1    -73.849374      Sung Shields        321510
# 2    -76.084009        Jodee Lupo        321520
# 3    -75.763898    Serafina Banda        321530
# 4    -75.284998    Angeles Crusoe        321540
# ..          ...               ...           ...
# 341 -122.640535   Nannie Brinkman        321960
# 342 -122.655247       Buffy Azure        321970
# 343 -122.669460  Khadijah Riemann        321970
# 344 -122.671880   Deanne Hertlein        321960
# 345 -122.657145      Jewell Likes        321970
#
# [346 rows x 7 columns]

# %%
pd.read_sql_query(sql = '''
SELECT *
FROM accounts
WHERE name NOT LIKE ('%s')
''', con = conn)
# Out:
#        id                name                    website        lat  \
# 0    1001             Walmart            www.walmart.com  40.238496
# 1    1011         Exxon Mobil         www.exxonmobil.com  41.169156
# 2    1021               Apple              www.apple.com  42.290495
# 3    1031  Berkshire Hathaway  www.berkshirehathaway.com  40.949021
# 4    1041            McKesson           www.mckesson.com  42.217093
# ..    ...                 ...                        ...        ...
# 265  4461                 KKR                www.kkr.com  45.545353
# 266  4471               Oneok              www.oneok.com  45.513513
# 267  4481      Newmont Mining            www.newmont.com  45.494117
# 268  4491                 PPL             www.pplweb.com  45.491720
# 269  4501         SpartanNash        www.spartannash.com  45.555651
#
#            long       primary_poc  sales_rep_id
# 0    -75.103297       Tamara Tuma        321500
# 1    -73.849374      Sung Shields        321510
# 2    -76.084009        Jodee Lupo        321520
# 3    -75.763898    Serafina Banda        321530
# 4    -75.284998    Angeles Crusoe        321540
# ..          ...               ...           ...
# 265 -122.655247       Buffy Azure        321970
# 266 -122.681500   Esta Engelhardt        321960
# 267 -122.669460  Khadijah Riemann        321970
# 268 -122.671880   Deanne Hertlein        321960
# 269 -122.657145      Jewell Likes        321970
#
# [270 rows x 7 columns]
