# %%
from sqlalchemy import create_engine
import pandas as pd
import urllib

# %%
conn = 'sqlite:///Weather_db_20200118.db'

# %%
pd.read_sql_query(con = conn, sql = 'SELECT * FROM sqlite_master WHERE type = "table"')
# Out:
#     type             name         tbl_name  rootpage  \
# 0  table        condition        condition         2
# 1  table  sqlite_sequence  sqlite_sequence         3
# 2  table         forecast         forecast         4
#
#                                                  sql
# 0  CREATE TABLE condition (_id INTEGER PRIMARY KE...
# 1             CREATE TABLE sqlite_sequence(name,seq)
# 2  CREATE TABLE forecast (_id INTEGER PRIMARY KEY...

# %%
condition_df = pd.read_sql_table(con = conn, table_name = "condition")

# %%
condition_df
# Out:
#        _id    city         country   region  chill  direction  speed  sunrise  \
# 0        1  Prague  Czech Republic   Prague      6        250   29.0  6:19 am
# 1        2  Prague  Czech Republic   Prague      5        250   30.0  6:19 am
# 2        3  Prague  Czech Republic   Prague      3        250   30.0  6:19 am
# 3        4  Prague  Czech Republic   Prague      5        250   26.0  6:19 am
# 4        5  Prague  Czech Republic   Prague      5        240   22.0  6:19 am
# ...    ...     ...             ...      ...    ...        ...    ...      ...
# 7252  7253  Prague  Czech Republic   Prague      2        225    3.0  7:52 am
# 7253  7254  Prague  Czech Republic   Prague      2        205    3.0  7:52 am
# 7254  7255  Prague  Czech Republic   Prague      0        215    7.0  7:52 am
# 7255  7256  Prague  Czech Republic   Prague      0        235    9.0  7:52 am
# 7256  7257  Prague  Czech Republic   Prague     -1        240   11.0  7:52 am
#
#        sunset  humidity  pressure  rising  visibility              pubdate  \
# 0     6:05 pm        45     975.0       0        16.1  2019-03-13 13:00:00
# 1     6:05 pm        42     975.0       0        16.1  2019-03-13 14:00:00
# 2     6:05 pm        46     974.0       0        16.1  2019-03-13 15:00:00
# 3     6:05 pm        42     974.0       0        16.1  2019-03-13 16:00:00
# 4     6:05 pm        49     974.0       0        16.1  2019-03-13 17:00:00
# ...       ...       ...       ...     ...         ...                  ...
# 7252  4:34 pm        93     991.0       0        13.0  2020-01-18 14:00:00
# 7253  4:34 pm        95     991.0       0        10.9  2020-01-18 15:00:00
# 7254  4:34 pm        94     991.0       0        11.3  2020-01-18 16:00:00
# 7255  4:34 pm        93     991.0       0        13.2  2020-01-18 17:00:00
# 7256  4:34 pm        92     992.0       0        14.3  2020-01-18 18:00:00
#
#                text  code  temperature              creatat  \
# 0            Breezy    23            9  2019-03-13 14:16:10
# 1            Breezy    23            8  2019-03-13 14:45:47
# 2            Breezy    23            7  2019-03-13 15:45:42
# 3            Breezy    23            8  2019-03-13 16:45:41
# 4     Partly Cloudy    30            7  2019-03-13 17:45:43
# ...             ...   ...          ...                  ...
# 7252         Cloudy    26            2  2020-01-18 14:45:21
# 7253         Cloudy    26            2  2020-01-18 15:45:23
# 7254         Cloudy    26            2  2020-01-18 16:45:23
# 7255         Cloudy    26            2  2020-01-18 17:45:30
# 7256         Cloudy    26            2  2020-01-18 18:45:23
#
#                  changeat
# 0     2019-03-13 14:16:10
# 1     2019-03-13 14:45:47
# 2     2019-03-13 15:45:42
# 3     2019-03-13 16:45:41
# 4     2019-03-13 17:45:43
# ...                   ...
# 7252  2020-01-18 14:45:21
# 7253  2020-01-18 15:45:23
# 7254  2020-01-18 16:45:23
# 7255  2020-01-18 17:45:30
# 7256  2020-01-18 18:45:23
#
# [7257 rows x 19 columns]

# %%
condition_df.dtypes
# Out:
# _id              int64
# city            object
# country         object
# region          object
# chill            int64
# direction        int64
# speed          float64
# sunrise         object
# sunset          object
# humidity         int64
# pressure       float64
# rising           int64
# visibility     float64
# pubdate         object
# text            object
# code             int64
# temperature      int64
# creatat         object
# changeat        object
# dtype: object

# %%
condition_df['sunrise'] = condition_df['sunrise'].astype('datetime64[ns]')
condition_df['sunset'] = condition_df['sunset'].astype('datetime64[ns]')
condition_df['pubdate'] = condition_df['pubdate'].astype('datetime64[ns]')
condition_df['creatat'] = condition_df['creatat'].astype('datetime64[ns]')
condition_df['changeat'] = condition_df['changeat'].astype('datetime64[ns]')

# %%
condition_df.dtypes
# Out:
# _id                     int64
# city                   object
# country                object
# region                 object
# chill                   int64
# direction               int64
# speed                 float64
# sunrise        datetime64[ns]
# sunset         datetime64[ns]
# humidity                int64
# pressure              float64
# rising                  int64
# visibility            float64
# pubdate        datetime64[ns]
# text                   object
# code                    int64
# temperature             int64
# creatat        datetime64[ns]
# changeat       datetime64[ns]
# dtype: object

# %%
quoted = urllib.parse.quote_plus("Driver={SQL Server};Server=DESKTOP-NO9U58U\SQLEXPRESS;Database=dbMoje;Trusted_Connection=yes;")
engine = create_engine('mssql+pyodbc:///?odbc_connect={}'.format(quoted))
df = pd.read_sql_table(con=engine, table_name = "Moje")
df
# Out:
#                                      ID                    TIME          TEXT
# 0  98812753-54BF-4B50-9864-543E2A4E4B6D 2020-07-19 10:45:12.000          Ahoj
# 1  52158BEA-E00D-4B0A-81EC-ED43C06DF2E9 2020-07-23 00:00:00.000  Western Camp
# 2  FC39A218-4EE6-4B38-B9CD-531A55A27D82 2020-07-23 07:06:03.617  Energylandia

# %%
condition_df.to_sql(con = engine, name = '20200118_condition')

# %%
df = pd.read_sql_table(con=engine, table_name = "20200118_condition")
df
# Out:
#       index   _id    city         country   region  chill  direction  speed  \
# 0         0     1  Prague  Czech Republic   Prague      6        250   29.0
# 1         1     2  Prague  Czech Republic   Prague      5        250   30.0
# 2         2     3  Prague  Czech Republic   Prague      3        250   30.0
# 3         3     4  Prague  Czech Republic   Prague      5        250   26.0
# 4         4     5  Prague  Czech Republic   Prague      5        240   22.0
# ...     ...   ...     ...             ...      ...    ...        ...    ...
# 7252   7252  7253  Prague  Czech Republic   Prague      2        225    3.0
# 7253   7253  7254  Prague  Czech Republic   Prague      2        205    3.0
# 7254   7254  7255  Prague  Czech Republic   Prague      0        215    7.0
# 7255   7255  7256  Prague  Czech Republic   Prague      0        235    9.0
# 7256   7256  7257  Prague  Czech Republic   Prague     -1        240   11.0
#
#                  sunrise              sunset  humidity  pressure  rising  \
# 0    2020-07-23 06:19:00 2020-07-23 18:05:00        45     975.0       0
# 1    2020-07-23 06:19:00 2020-07-23 18:05:00        42     975.0       0
# 2    2020-07-23 06:19:00 2020-07-23 18:05:00        46     974.0       0
# 3    2020-07-23 06:19:00 2020-07-23 18:05:00        42     974.0       0
# 4    2020-07-23 06:19:00 2020-07-23 18:05:00        49     974.0       0
# 3            Showers  2019-03-13 14:16:10  2019-03-13 14:16:10
# 4      Partly Cloudy  2019-03-13 14:16:10  2019-03-13 14:16:10
# ...              ...                  ...                  ...
# 72581  Partly Cloudy  2020-01-18 18:45:23  2020-01-18 18:45:23
# 72582   Mostly Sunny  2020-01-18 18:45:23  2020-01-18 18:45:23
# 72583  Mostly Cloudy  2020-01-18 18:45:23  2020-01-18 18:45:23
# 72584  Mostly Cloudy  2020-01-18 18:45:23  2020-01-18 18:45:23
# 72585  Partly Cloudy  2020-01-18 18:45:23  2020-01-18 18:45:23
#
# [72586 rows x 10 columns]

# %%
forecast_df.dtypes
# Out:
# _id          int64
# condate     object
# day         object
# date        object
# code         int64
# low          int64
# high         int64
# text        object
# creatat     object
# changeat    object
# dtype: object

# %%
forecast_df['condate'] = forecast_df['condate'].astype('datetime64[ns]')
forecast_df['date'] = forecast_df['date'].astype('datetime64[ns]')
forecast_df['creatat'] = forecast_df['creatat'].astype('datetime64[ns]')
forecast_df['changeat'] = forecast_df['changeat'].astype('datetime64[ns]')

# %%
forecast_df.dtypes
# Out:
# _id                  int64
# condate     datetime64[ns]
# day                 object
# date        datetime64[ns]
# code                 int64
# low                  int64
# high                 int64
# text                object
# creatat     datetime64[ns]
# changeat    datetime64[ns]
# dtype: object

# %%
forecast_df.to_sql(con = engine, name = '20200118_forecast')

# %%
df = pd.read_sql_table(con = engine, table_name = "20200118_forecast")

# %%
df
# Out:
#        index    _id             condate  day       date  code  low  high  \
# 0          0      1 2019-03-13 13:00:00  Wed 2019-03-13    12    3    10
# 1          1      2 2019-03-13 13:00:00  Thu 2019-03-14    12    4     7
# 2          2      3 2019-03-13 13:00:00  Fri 2019-03-15    12    4     9
# 3          3      4 2019-03-13 13:00:00  Sat 2019-03-16    11    6     9
# 4          4      5 2019-03-13 13:00:00  Sun 2019-03-17    30    6    16
# ...      ...    ...                 ...  ...        ...   ...  ...   ...
# 72581  72581  72582 2020-01-18 18:00:00  Thu 2020-01-23    30   -3     1
# 72582  72582  72583 2020-01-18 18:00:00  Fri 2020-01-24    34   -5     2
# 72583  72583  72584 2020-01-18 18:00:00  Sat 2020-01-25    28   -3     3
# 72584  72584  72585 2020-01-18 18:00:00  Sun 2020-01-26    28    0     5
# 72585  72585  72586 2020-01-18 18:00:00  Mon 2020-01-27    30    1     5
#
#                 text             creatat            changeat
# 0               Rain 2019-03-13 14:16:10 2019-03-13 14:16:10
# 1               Rain 2019-03-13 14:16:10 2019-03-13 14:16:10
# 2               Rain 2019-03-13 14:16:10 2019-03-13 14:16:10
# 3            Showers 2019-03-13 14:16:10 2019-03-13 14:16:10
# 4      Partly Cloudy 2019-03-13 14:16:10 2019-03-13 14:16:10
# ...              ...                 ...                 ...
# 72581  Partly Cloudy 2020-01-18 18:45:23 2020-01-18 18:45:23
# 72582   Mostly Sunny 2020-01-18 18:45:23 2020-01-18 18:45:23
# 72583  Mostly Cloudy 2020-01-18 18:45:23 2020-01-18 18:45:23
# 72584  Mostly Cloudy 2020-01-18 18:45:23 2020-01-18 18:45:23
# 72585  Partly Cloudy 2020-01-18 18:45:23 2020-01-18 18:45:23
#
# [72586 rows x 11 columns]
